# %%
import tensorflow as tf
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

print("TensorFlow :", tf._version_)
print("OpenCV     :", cv2._version_)
print("Numpy      :", np._version_)
print("GPU        :", tf.config.list_physical_devices('GPU'))
print("All libraries working!")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 7
#       4 import matplotlib.pyplot as plt
#       5 import pandas as pd
# ----> 7 print("TensorFlow :", tf._version_)
#       8 print("OpenCV     :", cv2._version_)
#       9 print("Numpy      :", np._version_)
#
# AttributeError: module 'tensorflow' has no attribute '_version_'
